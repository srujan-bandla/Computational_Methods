# %% [markdown]
# <a href="https://colab.research.google.com/github/srujan-bandla/srujan_INFO5731_Fall2022/blob/main/In_class_exercise/In_class_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (10/06/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand text representation.

# %% [markdown]
# Question 1 (10 points): Describe an interesting text classification or text mining task and explain what kind of features might be useful for you to build the machine learning model. List your features and explain why these features might be helpful. You need to list at least five different types of features.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

The text classification method which we would discuss over here is kind of extracting the data from the google colab
in the last in class assignment we extracted some papers from google colab so now we try to use them and extract the data
The feautures which might be helpfull in extracting is
Number of sentences, Number of words, Number of characters, Average word length, Number of special characters, 
Number of numerics,Number of uppercase words.
Number of sentences is usefull in finding out the how many snetences are present in the list
Number of words is usefull in finding out the how many words are present in the list
Number of characters is usefull in finding out the how many characters are present in the list
Average word length is usefull in finding out the average of words that are present in the list
Number of special characters is usefull in finding out the number of special characters that are present in the list
This features are helpful in organising the data and using them for the appropriate methods.

'''
# Out:
# '\nPlease write you answer here:\n\nThe text classification method which we would discuss over here is kind of extracting the data from the google colab\nin the last in class assignment we extracted some papers from google colab so now we try to use them and extract the data\nThe feautures which might be helpfull in extracting is\nNumber of sentences, Number of words, Number of characters, Average word length, Number of special characters, \nNumber of numerics,Number of uppercase words.\nNumber of sentences is usefull in finding out the how many snetences are present in the list\nNumber of words is usefull in finding out the how many words are present in the list\nNumber of characters is usefull in finding out the how many characters are present in the list\nAverage word length is usefull in finding out the average of words that are present in the list\nNumber of special characters is usefull in finding out the number of special characters that are present in the list\nThis features 
# ...

# %% [markdown]
# Question 2 (20 points): Write python code to extract these features you discussed above. You can collect a few sample text data for the feature extraction.

# %%
# You code here (Please add comments in the code):
from six.moves import urllib
import pandas as pd

t1 = []
url = "https://raw.githubusercontent.com/srujan-bandla/srujan_INFO5731_Fall2022/main/In_class_exercise/sampledata.txt"
tf = urllib.request.urlopen(url)  #This function is used to decode the url and get the data from it it is a predefined function

for i in tf:
    dec_data = i.decode("utf-8").replace('\r\n', '')    #this statement is used to decode the data present in the url and convert it into standard format
    if dec_data: 
        t1.append(dec_data)       #appending the decoded data to a list
df = pd.DataFrame (t1, columns = ['Text'])   #converting the list to data frame using pamdas
print(df)
# Out:
#                                                   Text
# 0                   Synonyms of about (Entry 1 of 3)\n
# 1                                 1having to do with\n
# 2    a POIGANT story about a young man who goes off...
# 3                                 Synonyms for about\n
# 4                                                   \n
# ..                                                 ...
# 117                                                 \n
# 118  asleep, dormant, dozing, napping, resting, sle...
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...
# 120                                      dreaming ME\n
# 121                           hypnotized, MESMERIZED\n
#
# [122 rows x 1 columns]

# %%
#To find Number of Sentences in a data frame

df['Num of sentences'] = df['Text'].apply(lambda y: len(str(y).split(".")))
df
# Out:
#                                                   Text  Num of sentences
# 0                   Synonyms of about (Entry 1 of 3)\n                 1
# 1                                 1having to do with\n                 1
# 2    a POIGANT story about a young man who goes off...                 1
# 3                                 Synonyms for about\n                 1
# 4                                                   \n                 1
# ..                                                 ...               ...
# 117                                                 \n                 1
# 118  asleep, dormant, dozing, napping, resting, sle...                 1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                 1
# 120                                      dreaming ME\n                 1
# 121                           hypnotized, MESMERIZED\n                 1
#
# [122 rows x 2 columns]

# %%
#To find Number of words in a data frame

df['Num of Words'] = df['Text'].apply(lambda y: len(str(y).split(" ")))
df
# Out:
#                                                   Text  Num of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                 1
# 1                                 1having to do with\n                 1
# 2    a POIGANT story about a young man who goes off...                 1
# 3                                 Synonyms for about\n                 1
# 4                                                   \n                 1
# ..                                                 ...               ...
# 117                                                 \n                 1
# 118  asleep, dormant, dozing, napping, resting, sle...                 1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                 1
# 120                                      dreaming ME\n                 1
# 121                           hypnotized, MESMERIZED\n                 1
#
#      Num of Words
# 0               7
# 1               4
# 2              12
# ...

# %%
#To find Number of characters in data frame

df['Num of Char'] = df['Text'].str.len()
df
# Out:
#                                                   Text  Num of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                 1
# 1                                 1having to do with\n                 1
# 2    a POIGANT story about a young man who goes off...                 1
# 3                                 Synonyms for about\n                 1
# 4                                                   \n                 1
# ..                                                 ...               ...
# 117                                                 \n                 1
# 118  asleep, dormant, dozing, napping, resting, sle...                 1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                 1
# 120                                      dreaming ME\n                 1
# 121                           hypnotized, MESMERIZED\n                 1
#
#      Num of Words  Num of Char
# 0               7           33
# ...

# %%
#To find the average word length of the list


def awl(x):
    jai = x.split() #here the sentence is being splitted into parts and being assigned to variable jai
    if len(jai) != 0:  #here we are checking if the variable is empty or not
        return(sum(len(deep) for deep in jai)/len(jai))
    else:
        return None

df['Avg Word Length'] = df['Text'].apply(lambda z: awl(z))
df
# Out:
#                                                   Text  Num of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                 1
# 1                                 1having to do with\n                 1
# 2    a POIGANT story about a young man who goes off...                 1
# 3                                 Synonyms for about\n                 1
# 4                                                   \n                 1
# ..                                                 ...               ...
# 117                                                 \n                 1
# 118  asleep, dormant, dozing, napping, resting, sle...                 1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                 1
# 120                                      dreaming ME\n                 1
# 121                           hypnotized, MESMERIZED\n                 1
#
#      Num of Words  Num of Char  Avg Word Length
# ...

# %%
#To find the number of special characters present in the list

def spchar(x):
    red = 0
    for i in range(len(x)):
        if not((x[i].isalpha()) and (x[i].isdigit())):
            red = red + 1
    return red

df['Num of spec char'] = df['Text'].apply(lambda y: spchar(y))
df
# Out:
#                                                   Text  Num of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                 1
# 1                                 1having to do with\n                 1
# 2    a POIGANT story about a young man who goes off...                 1
# 3                                 Synonyms for about\n                 1
# 4                                                   \n                 1
# ..                                                 ...               ...
# 117                                                 \n                 1
# 118  asleep, dormant, dozing, napping, resting, sle...                 1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                 1
# 120                                      dreaming ME\n                 1
# 121                           hypnotized, MESMERIZED\n                 1
#
#      Num of Words  Num of Char  Avg Word Length  Num of spec char
# ...

# %%
#To find the number of numerics present in the list

df['Num of num'] = df['Text'].apply(lambda x: len([x for x in x.split() if x.isdigit()])) #here we are considering it to be a seperate numeric if it is seperated with a space using the split function
df
# Out:
#                                                   Text  Num of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                 1
# 1                                 1having to do with\n                 1
# 2    a POIGANT story about a young man who goes off...                 1
# 3                                 Synonyms for about\n                 1
# 4                                                   \n                 1
# ..                                                 ...               ...
# 117                                                 \n                 1
# 118  asleep, dormant, dozing, napping, resting, sle...                 1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                 1
# 120                                      dreaming ME\n                 1
# 121                           hypnotized, MESMERIZED\n                 1
#
#      Num of Words  Num of Char  Avg Word Length  Num of spec char  Num of num
# ...

# %%
#To find number of uppercase words in a list

df['Num of upper case words'] = df['Text'].apply(lambda x: len([x for x in x.split() if x.isupper()])) #using split function we are finding the words with completely upper case
df
# Out:
#                                                   Text  Num of sentences  \
# 0                   Synonyms of about (Entry 1 of 3)\n                 1
# 1                                 1having to do with\n                 1
# 2    a POIGANT story about a young man who goes off...                 1
# 3                                 Synonyms for about\n                 1
# 4                                                   \n                 1
# ..                                                 ...               ...
# 117                                                 \n                 1
# 118  asleep, dormant, dozing, napping, resting, sle...                 1
# 119  dozy, drowsy, nodding, SLEEPY, slumberous (or ...                 1
# 120                                      dreaming ME\n                 1
# 121                           hypnotized, MESMERIZED\n                 1
#
#      Num of Words  Num of Char  Avg Word Length  Num of spec char  Num of num  \
# ...

# %%
df.to_csv('data.csv',index=True)

# %% [markdown]
# Question 3 (10 points): Use any of the feature selection methods mentioned in this paper "Deng, X., Li, Y., Weng, J., & Zhang, J. (2019). Feature selection for text classification: A review. Multimedia Tools & Applications, 78(3)." Select the most important features you extracted above, rank the features based on their importance in the descending order.

# %%
# You code here (Please add comments in the code):
''' Rank of most important features here:
1. Number of sentences
2. Number of Words
3. Number of Characters
4. Stowords
5. Lowercase
6. Removal of Punctuation '''

text_classifcation = (df['Text'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
text_classifcation.columns =['words', 'tf']
text_classifcation
# Out:
#      words  tf
# 0  1having   1
# 1       to   1
# 2       do   1
# 3   with\n   1

# %%
import numpy as np 

for i,word in enumerate(text_classifcation['words']):
  text_classifcation.loc[i, 'idf'] = np.log(df.shape[0]/(len(df[df['Text'].str.contains(word)])))

text_classifcation
# Out:
#      words  tf       idf
# 0  1having   1  4.804021
# 1       to   1  1.248673
# 2       do   1  2.858111
# 3   with\n   1  4.804021

# %%
text_classifcation['tfidf'] = text_classifcation['tf'] + text_classifcation['idf']
text_classifcation
# Out:
#      words  tf       idf     tfidf
# 0  1having   1  4.804021  5.804021
# 1       to   1  1.248673  2.248673
# 2       do   1  2.858111  3.858111
# 3   with\n   1  4.804021  5.804021
